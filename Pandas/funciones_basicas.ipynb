# %%
import pandas as pd

# %%
datos = {"nombre": ["Pedro", "Juan", "Alberto"], "edad": [18, 55, 24]}
datos
# Out:
# {'nombre': ['Pedro', 'Juan', 'Alberto'], 'edad': [18, 55, 24]}

# %%
df = pd.DataFrame(datos)
df
# Out:
#     nombre  edad
# 0    Pedro    18
# 1     Juan    55
# 2  Alberto    24

# %% [markdown]
# Los DATAFRAMES son la tabla

# %%
df["nombre"] #Esto es una serie del dataframe df
# Out:
# 0      Pedro
# 1       Juan
# 2    Alberto
# Name: nombre, dtype: object
