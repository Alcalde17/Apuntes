# %%
import pandas as pd
serie = pd.Series([5, 10, 15, 20, 25, 30, 35])
serie
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# 5    30
# 6    35
# dtype: int64

# %%
filtro = serie >= 20
serie_filtrada = serie[filtro]
serie_filtrada
# Out:
# 3    20
# 4    25
# 5    30
# 6    35
# dtype: int64

# %%
filtro
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
promedio = serie.mean()
print(promedio)
# Out:
# 20.0
