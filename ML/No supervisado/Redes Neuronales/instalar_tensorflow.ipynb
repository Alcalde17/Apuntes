# %%
# !pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    - -------------------------------------- 11.3/351.2 MB 58.7 MB/s eta 0:00:06
#    --- ------------------------------------ 27.5/351.2 MB 67.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 41.4/351.2 MB 67.7 MB/s eta 0:00:05
#    ------ --------------------------------- 56.1/351.2 MB 68.9 MB/s eta 0:00:05
#    -------- ------------------------------- 71.6/351.2 MB 69.5 MB/s eta 0:00:05
#    --------- ------------------------------ 85.7/351.2 MB 68.6 MB/s eta 0:00:04
#    ----------- --------------------------- 100.4/351.2 MB 69.2 MB/s eta 0:00:04
#    ------------ -------------------------- 115.3/351.2 MB 69.7 MB/s eta 0:00:04
#    -------------- ------------------------ 129.8/351.2 MB 69.9 MB/s eta 0:00:04
#    ---------------- ---------------------- 144.7/351.2 MB 69.7 MB/s eta 0:00:03
#    ----------------- --------------------- 157.8/351.2 MB 69.2 MB/s eta 0:00:03
# ...
